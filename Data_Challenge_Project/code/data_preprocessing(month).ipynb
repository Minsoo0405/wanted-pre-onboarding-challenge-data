# %% [markdown]
# # 📌 한번에 연도별 대여 이력 정보를 데이터프레임으로 변환하기

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ### 1.데이터 불러오기

# %% [markdown]
# #### 1.1 colab에서 데이터 로드

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import json

url = "/content/drive/MyDrive/rental_history_data/2018"
json_data = []

for i in range(1801,1813):
  with open(f"/content/drive/MyDrive/rental_history_data/2018/{i}.json", "r", encoding="utf-8") as f:
    for line in f:
      json_data.append(json.loads(line))
  print(f"{i}.json 파일 로드 완료")
# Out:
# 1801.json 파일 로드 완료
# 1802.json 파일 로드 완료
# 1803.json 파일 로드 완료
# 1804.json 파일 로드 완료
# 1805.json 파일 로드 완료
# 1806.json 파일 로드 완료
# 1807.json 파일 로드 완료
# 1808.json 파일 로드 완료
# 1809.json 파일 로드 완료
# 1810.json 파일 로드 완료
# 1811.json 파일 로드 완료
# 1812.json 파일 로드 완료

# %% [markdown]
# #### 1.2 vscode에서 데이터 로드

# %%
# import json

# url = "../rental_data/2018/"
# json_data = []

# for i in range(1801, 1813):
#     with open(url + f"{i}.json", "r", encoding="utf-8") as f:
#         for line in f:
# 	        json_data.append(json.loads(line))
#     print(f"{i}.json 파일 로드 완료")

# %% [markdown]
# ### 2.

# %%
len(json_data)
# Out:
# 9493

# %%
print(json_data[400].keys())
# Out:
# dict_keys(['rentData'])

# %%
print(json_data[7401])
# Out:
# {'rentData': {'list_total_count': '5', 'RESULT': {'CODE': 'INFO-000', 'MESSAGE': '정상 처리되었습니다.'}, 'row': [{'BIKE_ID': 'SPB-17732', 'RENT_DT': '2018-10-05 23:02:57', 'RENT_ID': '01257', 'RENT_NM': '가락시장역 사거리', 'RENT_HOLD': '3', 'RTN_DT': '2018-10-05 23:07:54', 'RTN_ID': '01243', 'RTN_NM': '문정 법조단지7', 'RTN_HOLD': '20', 'USE_MIN': '4', 'USE_DST': '1010.00', 'USR_CLS_CD': 'USR_001', 'BIRTH_YEAR': '1987', 'RENT_STATION_ID': 'ST-1076', 'RETURN_STATION_ID': 'ST-903', 'BIKE_SE_CD': 'LCD자전거', 'START_INDEX': 0, 'END_INDEX': 0, 'RNUM': '1'}, {'BIKE_ID': 'SPB-02260', 'RENT_DT': '2018-10-05 23:06:26', 'RENT_ID': '00502', 'RENT_NM': '뚝섬유원지역 1번출구 앞', 'RENT_HOLD': '9', 'RTN_DT': '2018-10-05 23:10:40', 'RTN_ID': '00548', 'RTN_NM': '자양나들목', 'RTN_HOLD': '5', 'USE_MIN': '3', 'USE_DST': '780.00', 'USR_CLS_CD': 'USR_001', 'SEX_CD': 'F', 'BIRTH_YEAR': '2000', 'RENT_STATION_ID': 'ST-99', 'RETURN_STATION_ID': 'ST-258', 'BIKE_SE_CD': 'LCD자전거', 'START_INDEX': 0, 'END_INDEX': 0, 'RNUM': '2'}, {'BIKE_ID': 'SPB-17
# ...

# %%
for i in range(4494,9493):
  if json_data[i].keys() == {"rentData"}:
    print(f"{i}.key is equal")
  else:
    print(f"{i}.key is not equal")
# Out:
# 4494.key is equal
# 4495.key is equal
# 4496.key is equal
# 4497.key is equal
# 4498.key is equal
# 4499.key is equal
# 4500.key is equal
# 4501.key is equal
# 4502.key is equal
# 4503.key is equal
# 4504.key is equal
# 4505.key is equal
# 4506.key is equal
# 4507.key is equal
# 4508.key is equal
# 4509.key is equal
# 4510.key is equal
# 4511.key is equal
# 4512.key is equal
# 4513.key is equal
# 4514.key is equal
# 4515.key is equal
# 4516.key is equal
# 4517.key is equal
# 4518.key is equal
# 4519.key is equal
# 4520.key is equal
# 4521.key is equal
# 4522.key is equal
# 4523.key is equal
# 4524.key is equal
# 4525.key is equal
# 4526.key is equal
# 4527.key is equal
# 4528.key is equal
# 4529.key is equal
# 4530.key is equal
# 4531.key is equal
# 4532.key is equal
# 4533.key is equal
# 4534.key is equal
# 4535.key is equal
# 4536.key is equal
# 4537.key is equal
# 4538.key is equal
# 4539.key is equal
# 4540.key is equal
# 4541.key is equal
# 4542.key is equal
# 4543.key is equal
# ...

# %%
if json_data[1].keys() == {"rentData"}:
  print("Yes")
else:
  print("No")
# Out:
# Yes

# %%
len_count = []


for i in range(0,7402):
  if json_data[i].keys() == {"rentData"}:
    len_count.append(len(json_data[i]["rentData"]['row']))

sum(len_count)
# Out:
# 4800885

# %%
json_df = pd.json_normalize(json_data[0]['rentData']['row'])
json_df.tail()
# Out:
#        BIKE_ID              RENT_DT RENT_ID            RENT_NM RENT_HOLD  \
# 274  SPB-12906  2018-01-01 00:53:53   01226        잠실4동 주민센터 옆         8
# 275  SPB-01786  2018-01-01 00:55:11   01226        잠실4동 주민센터 옆         7
# 276  SPB-12139  2018-01-01 00:54:50   00702          목4동주민센터 옆        16
# 277  SPB-08017  2018-01-01 00:59:38   01210  롯데월드타워(잠실역2번출구 쪽)         6
# 278  SPB-00774  2018-01-01 00:55:11   00702          목4동주민센터 옆        14
#
#                   RTN_DT RTN_ID       RTN_NM RTN_HOLD USE_MIN   USE_DST  \
# 274  2018-01-01 02:34:22  01445      용마지구대 A       10      96  11400.00
# 275  2018-01-01 02:34:43  01445      용마지구대 A        9      99  11640.00
# 276  2018-01-01 02:40:43  00703  오목교역 7번출구 앞       11     101   3720.00
# 277  2018-01-01 02:45:00  01230     송파중학교 정문        3     100   5080.00
# 278  2018-01-01 02:46:25  00703  오목교역 7번출구 앞        1     110   3870.00
#
#     USR_CLS_CD SEX_CD BIRTH_YEAR RENT_STATION_ID RETURN_STATION_ID BIKE_SE_CD  \
# ...

# %%
i = 1

while i < len(json_data):
    df = pd.json_normalize(json_data[i]['rentData']['row'])
    json_df = pd.concat([json_df, df], axis=0)

    if len(df) != len(json_df):
        print(f"{i}번째 DataFrame concat 성공")

    i += 1

print("DataFrame concat 완료!!!")
# Out:
# 1번째 DataFrame concat 성공
# 2번째 DataFrame concat 성공
# 3번째 DataFrame concat 성공
# 4번째 DataFrame concat 성공
# 5번째 DataFrame concat 성공
# 6번째 DataFrame concat 성공
# 7번째 DataFrame concat 성공
# 8번째 DataFrame concat 성공
# 9번째 DataFrame concat 성공
# 10번째 DataFrame concat 성공
# 11번째 DataFrame concat 성공
# 12번째 DataFrame concat 성공
# 13번째 DataFrame concat 성공
# 14번째 DataFrame concat 성공
# 15번째 DataFrame concat 성공
# 16번째 DataFrame concat 성공
# 17번째 DataFrame concat 성공
# 18번째 DataFrame concat 성공
# 19번째 DataFrame concat 성공
# 20번째 DataFrame concat 성공
# 21번째 DataFrame concat 성공
# 22번째 DataFrame concat 성공
# 23번째 DataFrame concat 성공
# 24번째 DataFrame concat 성공
# 25번째 DataFrame concat 성공
# 26번째 DataFrame concat 성공
# 27번째 DataFrame concat 성공
# 28번째 DataFrame concat 성공
# 29번째 DataFrame concat 성공
# 30번째 DataFrame concat 성공
# 31번째 DataFrame concat 성공
# 32번째 DataFrame concat 성공
# 33번째 DataFrame concat 성공
# 34번째 DataFrame concat 성공
# 35번째 DataFrame concat 성공
# 36번째 DataFrame concat 성공
# 37번째 DataFrame concat 성공
# ...
